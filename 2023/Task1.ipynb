# %% [markdown]
# # Task 1

# %% [markdown]
# ## Setup

# %%
# !pip install librosa pydub pysoundfile SpeechRecognition

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

# %%
import librosa

CWD = '/content/drive/MyDrive/Colab Notebooks/CSIT/CSIT_DS_Mini-Challenge/CSIT_DS_Mini-Challenge/'

audio, sr = librosa.load(f'{CWD}Task_1/T1_audio.wav')

# %%
audio.shape
# Out:
# (584766,)

# %%
reversed_audio = audio[::-1]

# %% [markdown]
# ## Plot audio wavelength

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(audio, sr=sr)

# %%
librosa.display.waveshow(reversed_audio, sr=sr)

# %% [markdown]
# ## Playing and writing audio

# %%
import IPython.display as ipd
ipd.Audio(f'{CWD}Task_1/T1_audio.wav') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(reversed_audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import soundfile as sf

# Write audio output from array
sf.write(f'{CWD}Task_1/T1_audio_reversed.wav', reversed_audio, samplerate=sr)

# %% [markdown]
# ## Transcribe audio

# %%
import speech_recognition as sr
from pydub import AudioSegment

r = sr.Recognizer()
with sr.AudioFile(f'{CWD}Task_1/T1_audio_reversed.wav') as src:
    aux = r.record(src)
    print(f"Transcription: {r.recognize_google(aux)}")
# Out:
# Transcription: latitude 67.922 degrees North longitude 26.5 5046 degrees east

# %% [markdown]
# ## Mapping the location

# %%
# !pip install folium

# %%
import folium

political_countries_url = (
    "http://geojson.xyz/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson"
)

m = folium.Map(location=(67.922, 26.5046), tiles="cartodb positron")
folium.GeoJson(political_countries_url).add_to(m)
m
# Out:
# Output hidden; open in https://colab.research.google.com to view.
